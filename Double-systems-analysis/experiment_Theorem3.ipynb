# %% [markdown]
# # This is the Juypter Notebook containing simulations for Theorem 3 in the paper "Networked Competitive Bivirus SIS Model - Analysis of the Discrete-Time Case"

# %%
import bivirus
import numpy as np

# %%
# configurations of the experiment
config = bivirus.SimulationConfig(N=20, h=0.001, W=0.5, iterations=10000, tolerance=1e-4)

# random seed for reproducibility
seed = 1049
np.random.seed(seed)

# parameters of the model
B1, B2 = np.random.uniform(0, config.W, (config.N, config.N)), np.random.uniform(0, config.W, (config.N, config.N))
B1, B2 = np.round(B1, 2), np.round(B2, 2)

B = [B1, B2]
delta = [
    10 * np.ones(config.N),
    1 * np.ones(config.N)
]
print("B1 is:", B1)
print()
print("B2 is:", B2)
# Out:
# B1 is: [[0.38 0.42 0.2  0.17 0.32 0.08 0.22 0.07 0.19 0.27 0.21 0.04 0.04 0.27
#   0.16 0.35 0.26 0.39 0.42 0.26]
#  [0.24 0.45 0.03 0.11 0.47 0.44 0.14 0.07 0.4  0.5  0.08 0.01 0.05 0.08
#   0.23 0.48 0.05 0.46 0.32 0.29]
#  [0.25 0.29 0.27 0.45 0.32 0.36 0.08 0.46 0.28 0.25 0.36 0.22 0.06 0.41
#   0.38 0.38 0.23 0.27 0.38 0.32]
#  [0.01 0.43 0.44 0.06 0.35 0.42 0.1  0.25 0.47 0.14 0.19 0.36 0.41 0.28
#   0.5  0.06 0.16 0.1  0.29 0.38]
#  [0.23 0.25 0.09 0.33 0.02 0.46 0.17 0.37 0.47 0.48 0.4  0.   0.05 0.21
#   0.41 0.04 0.4  0.03 0.04 0.09]
#  [0.29 0.15 0.13 0.22 0.39 0.14 0.42 0.16 0.34 0.12 0.25 0.08 0.44 0.26
#   0.27 0.22 0.48 0.01 0.31 0.  ]
#  [0.37 0.2  0.41 0.07 0.33 0.34 0.28 0.41 0.41 0.17 0.48 0.34 0.07 0.35
#   0.26 0.02 0.34 0.18 0.34 0.34]
#  [0.37 0.29 0.07 0.49 0.44 0.48 0.01 0.24 0.44 0.22 0.21 0.17 0.04 0.05
#   0.46 0.12 0.24 0.1  0.14 0.  ]
#  [0.35 0.07 0.46 0.24 0.14 0.38 0.2  0.11 0.18 0.37 0.17 0.42 0.17 0.16
#   0.34 0.3  0.48 0.29 0.1  0.02]
#  [0.28 0.43 0.39 0.39 0.43 0.47 0.15 0.32 0.18 0.28 0.13 0.49 0.08 0.18
#   0.14 0.17 0.26 0.44 0.22 0.41]
#  [0.26 0.13 0.39 0.04 0.08 0.02 0.31 0.16 0.37 0.07 0.37 0.31 0.16 0.15
#   0.34 0.2  0.13 0.12 0.5  0.4 ]
#  [0.16 0.13 0.23 0.02 0.11 0.3  0.37 0.33 0.3  0.23 0.24 0.27 0.39 0.31
#   0.28 0.   0.19 0.5  0.19 0.37]
#  [0.35 0.03 0.39 0.27 0.02 0.05 0.3  0.11 0.38 0.28 0.25 0.08 0.01 0.31
#   0.42 0.1  0.03 0.33 0.2  0.33]
#  [0.23 0.07 0.25 0.14 0.35 0.23 0.07 0.08 0.01 0.38 0.14 0.01 0.05 0.16
#   0.22 0.12 0.36 0.42 0.43 0.14]
#  [0.2  0.03 0.36 0.12 0.44 0.25 0.32 0.42 0.18 0.   0.23 0.42 0.43 0.43
#   0.08 0.27 0.15 0.1  0.05 0.29]
#  [0.17 0.42 0.3  0.47 0.36 0.06 0.27 0.31 0.11 0.12 0.23 0.12 0.08 0.34
#   0.49 0.32 0.38 0.37 0.49 0.3 ]
#  [0.   0.2  0.1  0.05 0.05 0.45 0.2  0.48 0.23 0.39 0.13 0.25 0.02 0.34
#   0.41 0.23 0.22 0.36 0.32 0.26]
#  [0.39 0.23 0.16 0.4  0.19 0.22 0.4  0.04 0.22 0.27 0.41 0.02 0.01 0.46
#   0.36 0.45 0.14 0.48 0.2  0.03]
#  [0.34 0.1  0.14 0.06 0.26 0.16 0.48 0.43 0.02 0.19 0.14 0.14 0.03 0.12
#   0.16 0.27 0.14 0.45 0.08 0.18]
#  [0.13 0.05 0.12 0.33 0.42 0.17 0.01 0.22 0.42 0.47 0.36 0.34 0.04 0.11
#   0.35 0.03 0.4  0.33 0.05 0.19]]
#
# B2 is: [[0.39 0.32 0.09 0.18 0.16 0.07 0.24 0.39 0.07 0.4  0.03 0.26 0.38 0.08
#   0.19 0.42 0.25 0.3  0.21 0.29]
#  [0.23 0.33 0.28 0.46 0.3  0.22 0.12 0.34 0.15 0.41 0.2  0.17 0.28 0.38
#   0.49 0.05 0.23 0.13 0.01 0.05]
#  [0.44 0.48 0.23 0.08 0.21 0.02 0.25 0.41 0.48 0.2  0.36 0.48 0.04 0.17
#   0.45 0.13 0.48 0.01 0.15 0.41]
#  [0.5  0.37 0.15 0.44 0.16 0.17 0.37 0.35 0.03 0.13 0.17 0.34 0.06 0.42
#   0.45 0.39 0.06 0.06 0.22 0.18]
#  [0.41 0.33 0.48 0.42 0.14 0.07 0.07 0.17 0.2  0.02 0.41 0.29 0.21 0.43
#   0.32 0.11 0.29 0.49 0.12 0.42]
#  [0.03 0.21 0.36 0.44 0.31 0.05 0.39 0.04 0.4  0.01 0.24 0.24 0.16 0.19
#   0.43 0.11 0.16 0.33 0.45 0.44]
#  [0.44 0.36 0.01 0.08 0.2  0.38 0.48 0.   0.01 0.09 0.06 0.01 0.46 0.25
#   0.21 0.46 0.07 0.3  0.33 0.45]
#  [0.16 0.12 0.29 0.49 0.31 0.06 0.17 0.19 0.3  0.48 0.32 0.23 0.   0.3
#   0.1  0.36 0.5  0.19 0.4  0.4 ]
#  [0.06 0.02 0.29 0.01 0.1  0.23 0.22 0.34 0.17 0.23 0.08 0.15 0.44 0.11
#   0.16 0.44 0.28 0.47 0.23 0.48]
#  [0.03 0.25 0.02 0.2  0.21 0.03 0.12 0.   0.48 0.45 0.46 0.26 0.11 0.29
#   0.04 0.31 0.3  0.49 0.48 0.23]
#  [0.17 0.47 0.46 0.16 0.47 0.2  0.04 0.36 0.42 0.13 0.1  0.26 0.43 0.03
#   0.31 0.43 0.44 0.13 0.39 0.36]
#  [0.25 0.   0.2  0.25 0.28 0.17 0.06 0.05 0.23 0.03 0.42 0.32 0.33 0.26
#   0.24 0.31 0.05 0.28 0.24 0.11]
#  [0.42 0.05 0.35 0.49 0.39 0.19 0.43 0.1  0.33 0.32 0.35 0.44 0.15 0.46
#   0.36 0.49 0.22 0.09 0.5  0.04]
#  [0.12 0.29 0.38 0.19 0.04 0.3  0.21 0.12 0.24 0.41 0.11 0.34 0.35 0.07
#   0.03 0.14 0.   0.47 0.17 0.45]
#  [0.31 0.21 0.04 0.2  0.29 0.22 0.09 0.01 0.32 0.2  0.27 0.46 0.44 0.13
#   0.32 0.33 0.12 0.01 0.13 0.44]
#  [0.35 0.1  0.39 0.39 0.06 0.5  0.37 0.08 0.06 0.03 0.36 0.46 0.11 0.43
#   0.25 0.2  0.29 0.43 0.05 0.29]
#  [0.03 0.41 0.4  0.16 0.24 0.2  0.26 0.4  0.32 0.16 0.02 0.37 0.32 0.04
#   0.32 0.19 0.08 0.05 0.22 0.08]
#  [0.26 0.33 0.27 0.46 0.01 0.48 0.17 0.27 0.13 0.23 0.43 0.34 0.04 0.06
#   0.39 0.31 0.03 0.43 0.05 0.04]
#  [0.05 0.45 0.18 0.4  0.02 0.06 0.4  0.27 0.22 0.27 0.35 0.44 0.09 0.35
#   0.49 0.3  0.08 0.13 0.04 0.27]
#  [0.29 0.24 0.21 0.46 0.26 0.03 0.49 0.38 0.3  0.23 0.27 0.47 0.39 0.28
#   0.43 0.33 0.16 0.4  0.2  0.05]]

# %%
# check assumptions of the theorems
print("Assumptions of theorems:")
print("Theorem 2 satisfied:", bivirus.check_theorem_2(B, delta, config))
print("Theorem 3:", bivirus.check_theorem_3(B, delta, config))
# print("Theorem 4:", bivirus.check_theorem_4(B, delta))
# Out:
# Assumptions of theorems:
# spectral radius 1 is 0.994877043820584
# spectral radius 2 is 1.00397334825823
# Theorem 2 satisfied: False
# Theorem 3: 3.2

# %%
# run simulation with 9 random initial conditions
# and plot the results in a 3x3 grid
x1_avg_histories = []
x2_avg_histories = []

for i in range(9):
    x1 = np.random.uniform(0, 1, config.N)
    x2 = np.random.uniform(0, 1 - x1, config.N)
    bivirus.check_basic_assumptions(x1, x2, B, delta, config)
    results = bivirus.run_simulation(x1, x2, B, delta, config)
    x1_avg_histories.append(results["x1_avg_history"])
    x2_avg_histories.append(results["x2_avg_history"])
bivirus.plot_simulation_3by3(x1_avg_histories, x2_avg_histories, yscale='log')
# Out:
# All assumptions satisfied
# Converged at iteration 1698
# All assumptions satisfied
# Converged at iteration 1576
# All assumptions satisfied
# Converged at iteration 1741
# All assumptions satisfied
# Converged at iteration 1596
# All assumptions satisfied
# Converged at iteration 1546
# All assumptions satisfied
# Converged at iteration 1530
# All assumptions satisfied
# Converged at iteration 1546
# All assumptions satisfied
# Converged at iteration 1540
# All assumptions satisfied
# Converged at iteration 1467
